# %% [markdown]
# ## Variables

# %%
x = 5

# %%
x

# %%
y = 8

# %%
Y

# %%
print (y)

# %%
x,y = (1,2)

# %%
x

# %%
y

# %%
x,y = (1,2,3)

# %% [markdown]
# ## Numbers and Boolean Values

# %%
x1 = 5

# %%
type(x1)

# %%
type(-6)

# %%
x2 = 4.75

# %%
type(x2)

# %%
int(x2)

# %%
float(5)

# %%
x3 = True

# %%
type(x3)

# %%
x3 = true

# %% [markdown]
# ## Strings

# %%
George

# %%
'George'

# %%
"George"

# %%
print ('George')

# %%
print ("George")

# %%
x4 = "George"

# %%
x4

# %%
y = 10
print (y + "Dollars")

# %%
y = 10
print (str(y) + " Dollars")

# %%
'I'm fine'

# %%
"I'm fine"

# %%
'I\'m fine'

# %%
'Press "Enter"'

# %%
'Red' 'car'

# %%
'Red ' 'car'

# %%
'Red ' + 'car'

# %%
print ('Red ' + 'car')

# %%
print ('Red', 'car')

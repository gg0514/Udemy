# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# pip install langchain_openai==0.3.7
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama

# llm = ChatOpenAI(model="gpt-4o-mini")
# llm = ChatOllama(model="gemma3:4b")
llm = ChatOllama(model="gemma3:1b")

messages = [
    ("system", "사용자가 입력한 문장을 영어로 번역해."),
    ("human", "내일은 피자를 먹어야지!")
]

result = llm.invoke(messages)
result
# Out:
# AIMessage(content='There are a few ways to translate "내일은 피자를 먹어야지!" into English, depending on the nuance you want to convey:\n\n* **Most common & natural:** "I\'m going to have pizza tomorrow!"\n* **Slightly more emphatic:** "I\'m going to eat pizza tomorrow!"\n* **More casual:** "Tomorrow, I\'m having pizza!"\n\nWould you like me to explain the difference between them?', additional_kwargs={}, response_metadata={'model': 'gemma3:4b', 'created_at': '2026-03-19T00:00:25.7120893Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9650464800, 'load_duration': 272604500, 'prompt_eval_count': 35, 'prompt_eval_duration': 112988200, 'eval_count': 94, 'eval_duration': 9187223300, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'}, id='lc_run--019d0364-92bc-72f0-a659-2855825468f3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 94, 'total_tokens': 129})

# %%
result.content
# Out:
# 'There are a few ways to translate "내일은 피자를 먹어야지!" into English, depending on the nuance you want to convey:\n\n* **Most common & natural:** "I\'m going to have pizza tomorrow!"\n* **Slightly more emphatic:** "I\'m going to eat pizza tomorrow!"\n* **More casual:** "Tomorrow, I\'m having pizza!"\n\nWould you like me to explain the difference between them?'

# %%
# pip install langchain==0.3.19
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
messages = [
    SystemMessage(content="사용자가 입력한 문장을 영어로 번역해."),
    HumanMessage(content="오늘은 피자를 먹어야지!")
]

result = llm.invoke(messages)
result.content
# Out:
# "Let's get some pizza today!"

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# "Let's get some pizza today!"

# %%
chain = llm | parser
chain.invoke(messages)
# Out:
# "Let's get some pizza today!"

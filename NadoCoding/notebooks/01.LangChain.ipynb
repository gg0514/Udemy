# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# pip install langchain_openai==0.3.7
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama

# llm = ChatOpenAI(model="gpt-4o-mini")
llm = ChatOllama(model="gemma3:1b")

messages = [
    ("system", "사용자가 입력한 문장을 영어로 번역해."),
    ("human", "내일은 피자를 먹어야지!")
]

result = llm.invoke(messages)
result
# Out:
# AIMessage(content='Okay, here are a few ways to translate "내일은 피자를 먹어야지!" (Nae-il-eun pi-a-ra meogeot-eodo-ji!) into English, with slightly different nuances:\n\n* **"I\'m going to eat pizza tomorrow, right?"** - This is a very common and natural way to express the sentiment.\n* **"Tomorrow, I\'m going to have pizza!"** -  A slightly more emphatic way of saying it.\n* **"Let\'s eat pizza tomorrow, yeah?"** - This adds a casual, friendly tone.\n\n**Which one is best depends on the context and your desired tone.**\n\nWould you like me to give you a more casual or formal translation?', additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2026-03-18T09:45:11.0419237Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6329401000, 'load_duration': 268423000, 'prompt_eval_count': 35, 'prompt_eval_duration': 365654300, 'eval_count': 159, 'eval_duration': 5559177500, 'logprobs': None, 'model_name': 'gemma3:1b', 'model_provider': 'ollama'}, id='lc_run--019d0055-9fc7-76e1-ac47-864d555c3f54-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 159, 'total_tokens': 194})

# %%
result.content
# Out:
# 'Okay, here are a few ways to translate "내일은 피자를 먹어야지!" (Nae-il-eun pi-a-ra meogeot-eodo-ji!) into English, with slightly different nuances:\n\n* **"I\'m going to eat pizza tomorrow, right?"** - This is a very common and natural way to express the sentiment.\n* **"Tomorrow, I\'m going to have pizza!"** -  A slightly more emphatic way of saying it.\n* **"Let\'s eat pizza tomorrow, yeah?"** - This adds a casual, friendly tone.\n\n**Which one is best depends on the context and your desired tone.**\n\nWould you like me to give you a more casual or formal translation?'

# %%
# pip install langchain==0.3.19
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
messages = [
    SystemMessage(content="사용자가 입력한 문장을 영어로 번역해."),
    HumanMessage(content="오늘은 피자를 먹어야지!")
]

result = llm.invoke(messages)
result.content
# Out:
# 'Here are a few options for translating "오늘은 피자를 먹어야지!" into English, with slightly different nuances:\n\n* **Today I have to eat pizza!** (Most straightforward and common)\n* **I have to eat pizza today!** (Emphasizes the obligation)\n* **I’m going to eat pizza today, let’s go!** (Adds a bit of enthusiasm)\n\nWhich one is best depends on the context!'

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# 'Here are a few options for translating "오늘은 피자를 먹어야지!" into English, with slightly different nuances:\n\n* **Today I have to eat pizza!** (Most straightforward and common)\n* **I have to eat pizza today!** (Emphasizes the obligation)\n* **I’m going to eat pizza today, let’s go!** (Adds a bit of enthusiasm)\n\nWhich one is best depends on the context!'

# %%
chain = llm | parser
chain.invoke(messages)
# Out:
# 'Here are a few ways to translate "오늘은 피자를 먹어야지!" into English, depending on the nuance you want to convey:\n\n* **"Let\'s eat pizza today!"** - This is a casual and enthusiastic translation.\n* **"I have to eat pizza today!"** -  This emphasizes the obligation to eat pizza.\n* **"I\'m going to eat pizza today!"** - This is a slightly more active and definitive translation.\n\nWould you like me to provide a more formal or context-specific translation?'

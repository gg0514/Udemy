# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-4o-mini")
parser = StrOutputParser()

chain = llm | parser

# %%
from langchain_core.messages import HumanMessage, AIMessage
chain.invoke(
    [
        HumanMessage(content="내일은 수영을 가야지!")
    ]
)
# Out:
# '수영을 가는 게 좋겠네요! 즐거운 시간 되세요. 어떤 수영 스타일을 좋아하시나요?'

# %%
chain.invoke(
    [
        HumanMessage(content="내일 뭐하러 간다고 했지?")
    ]
)
# Out:
# '내일 어떤 계획이 있었는지 기억이 나지 않으시군요. 혹시 친구나 가족과의 약속, 업무 관련 일정, 혹은 취미 활동 같은 것들이 있을까요? 다시 한번 생각해보시면 도움이 될 것 같아요.'

# %%
chain.invoke(
    [
        HumanMessage(content="내일은 수영을 가야지!"),
        AIMessage(content="좋아요! 수영은 훌륭한 운동이에요. 어떤 스타일을 수영할 계획이신가요? 프리, 배영, 접영, 아니면 평영?"),
        HumanMessage(content="내일 뭐하러 간다고 했지?")
    ]
)
# Out:
# '내일 수영을 가신다고 하셨어요! 준비는 다 했나요? 수영복이나 수경 챙기셨나요?'
